# %% [markdown]
# # 第五讲 数据分析中的数学、统计描述和假设检验

# %% [markdown]
# ## 第一部分 数据分析中的数学 ##

# %% [markdown]
# 从欧拉恒等式讲起
#
# $$ e^{i\pi} + 1 = 0$$
#
# $$ e^{ix} = \cos(x) + i\sin(x)$$
#
# ### 1. 数学是什么？
# ![数学](.\map-mathematics.jpg)
#
# [B站：数学地图 @圆桌字幕组](https://www.bilibili.com/video/BV1ex411r787?from=search&seid=1561328760674428847)
#
# ### 2. 数据分析用到哪些数学？
#
# - **概率**
#
# 概率是一个抽象概念。它的分母，是要把所有假设样本空间Ω取尽的一种抽象，而现实中这一般是很难办到的。
#
# ---
#
# >概率为零的事件不一定是**不可能事件**，比如：
# >
# >a. 在任意实数区间\[a, b\]内随机取一点，它正好是某一值（比如$ (a + b)\over 2$）的概率
# >
# >b. 随手抛一次均匀硬币，它是立着的概率
# >
# >而**不可能事件**的概率一定为零！
#
# ---
#
# 概率论、统计学就是研究概率并应用的数学分支。数据分析中大量应用概率论与统计学知识，学习者应当掌握包括概率、频率、期望、均值、方差、协方差、贝叶斯变换等基本概念，并能进行统计描述和假设检验。
#
# - **代数**
#
# 线性代数知识在数据处理中广泛应用，特别是在数据挖掘、机器学习、神经网络中使用频率极高，有志于从事数据分析专业工作的学习者应夯实自己的线代基础，包括矩阵基础知识、克莱姆法则、矩阵作为一种映射、特征值、特征向量、PCA等。
#
# - **分析**
#
# 分析学是数学的主要分支之一，以微积分方法为基本工具，以函数（映射、关系等更丰富的内涵）为主要研究对象，以极限为基本思想的众多数学经典分支及其现代拓展的统称。
#
# 分析学在数据分析中的应用主要在机器学习部分，如反向传播、回归、激活函数、LOSS函数等，需要学习者掌握导数、偏导、梯度下降、$Beta$函数、$Taylor$展开等。
#
# - **图论**
#
# 由于概率图模型的需要，学习者应掌握一些基本的图论知识，譬如完全图的路径数的计算方法。

# %% [markdown]
# ### 3. 课程安排
#
# 数学部分安排两周。
#
# 本周着重讲概率统计学的应用，也即统计描述和假设检验。
#
# 下周着重讲线性代数相关知识。

# %% [markdown]
# ## 第二部分 统计学速览##
#
# #### .1 基本概念
#
# **统计学**是从一组数据中抽象出有用信息以支持决策的原理和方法。统计学的研究领域或方法分为两部分：统计描述 Descriptive Statistics和统计推断 Inferential Statistics。
#
# A **population （总体）** is the complete collection of all elements to be studied. The collection is complete in the sense that it includes all subjects to be studied.
#
# A **parameter（参数）** is a numerical measurement describing some characteristic of a population.
#
# A **sample（样本）** is a sub-collection of elements drawn from a population.
#
# A **Statistic（统计量）** is a numerical measurement describing some characteristic of a sample.
#
# #### .2 统计描述
#
# - 定义
#
# 整理、概括并提供数据的方法以便看出数据间有用的关系
#
# >使用曲线图、饼图、条形图、表格等
#
# - 内容
#
# 收集数据 Collecting Data
#
# 演示数据 Presenting Data
#
# 把握数据特征 Characterizing Data
#
# >集中趋势、变异程度、分布形状
#
# - 目标
#
# 描述数据 Describe Data
#
# #### .3 统计推断
#
# - 定义
#
# 利用从总体的一个样本中获得的信息来推断总体的特征时使用的方法
#
# - 内容
#
# 统计估计 Estimation，包括参数估计（点估计；区间估计）和非参数估计
#
# 假设检验 Hypothesis Testing，包括参数检验和非参数检验
#
# - 目标
#
# 确定总体的特征 Make Decisions About Population Characteristics
#
# #### .4 数据
#
# - 数值数据 (定量的)
#
# 分为连续数值数据、离散数值数据、定距数值数据，以及时间日期数据等其他特殊格式数据。
#
# - 属性数据 (定性的)
#
# 分为分类数据、有序数据等。
#
# 让我们看一看实际的数据样例。

# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt
from scipy import stats

# %%
cars = pd.read_csv("cars.csv", encoding = "ISO-8859-1")

# %%
cars.head(10)
# Out:
#                        Make                                        Model  \
# 0       Ashok Leyland Stile        Ashok Leyland Stile LE 8-STR (Diesel)
# 1       Ashok Leyland Stile        Ashok Leyland Stile LS 8-STR (Diesel)
# 2       Ashok Leyland Stile        Ashok Leyland Stile LX 8-STR (Diesel)
# 3       Ashok Leyland Stile        Ashok Leyland Stile LS 7-STR (Diesel)
# 4       Ashok Leyland Stile  Ashok Leyland Stile LS 7-STR Alloy (Diesel)
# 5       Ashok Leyland Stile        Ashok Leyland Stile LX 7-STR (Diesel)
# 6       Ashok Leyland Stile  Ashok Leyland Stile LX 7-STR Alloy (Diesel)
# 7       Aston Martin Rapide            Aston Martin Rapide LUXE (Petrol)
# 8     Aston Martin Rapide S               Aston Martin Rapide S (Petrol)
# 9  Aston Martin V12 Vantage      Aston Martin V12 Vantage Coupe (Petrol)
#
#    Price   Type   ABS  BootSpace    GearType AirBag  Engine  FuelCapacity  \
# 0    750    MPV    No      500.0      Manual     No  1461.0          50.0
# ...

# %%
cars.tail(10)
# Out:
#                         Make                                Model  Price  \
# 823                Volvo S60         Volvo S60 Summum D5 (Diesel)   3690
# 824                Volvo S60                         Volvo S60 T6   4200
# 825                Volvo S80         Volvo S80 Summum D4 (Diesel)   4135
# 826                Volvo S80         Volvo S80 Summum D5 (Diesel)   4480
# 827                Volvo V40        Volvo V40 D3 Kinetic (Diesel)   2475
# 828                Volvo V40       Volvo V40 D3 R-Design (Diesel)   2770
# 829  Volvo V40 Cross Country  Volvo V40 D3 Cross Country (Diesel)   3180
# 830  Volvo V40 Cross Country  Volvo V40 T4 Cross Country (Petrol)   3240
# 831               Volvo XC90      Volvo XC 90 D5 Momentum(Diesel)   6490
# 832               Volvo XC90   Volvo XC 90 D5 Inscription(Diesel)   7790
#
#           Type   ABS  BootSpace    GearType AirBag  Engine  FuelCapacity  \
# 823      Sedan   Yes      339.0   Automatic    Yes  2400.0          67.5
# ...

# %%
cars.shape
# Out:
# (833, 11)

# %%
cars.columns
# Out:
# Index(['Make', 'Model', 'Price', 'Type', 'ABS', 'BootSpace', 'GearType',
#        'AirBag', 'Engine', 'FuelCapacity', 'Mileage'],
#       dtype='object')

# %%
cars.dtypes
# Out:
# Make             object
# Model            object
# Price             int64
# Type             object
# ABS              object
# BootSpace       float64
# GearType         object
# AirBag           object
# Engine          float64
# FuelCapacity    float64
# Mileage         float64
# dtype: object

# %%
cars.isnull().sum()
# Out:
# Make              0
# Model             0
# Price             0
# Type              0
# ABS              16
# BootSpace       179
# GearType         16
# AirBag           21
# Engine            7
# FuelCapacity      0
# Mileage         171
# dtype: int64

# %% [markdown]
# #### 1.5 滥用统计（Abuses of statistics）
#
# - 样本问题
#
# 不好的样本（Bad samples）
# 			E.g. a self-selected survey
#
# 小样本（Small samples）
# 			Even large samples can be bad samples.
#
# 加条件的问题（Loaded questions）
# 		E.g. 90% yes: “Is a 1.80-hight man high, or not”
# 		       10% yes: “Is a 1.80-hight man in US high, or not”
#
# - 误导性图表
# ![](misleading_1.png)
#
# ![](misleading_2.png)
#
# - Other
#
# 		Precise numbers
# 			E.g. Yichi Zhang, the 1300000000th person of China, was born in January 6, 2005 in Beijing. (It is better to state the number of Chinese people is about 1.3 billion by January 6, 2005 )
#
# 		Distorted percentage
# 			E.g. the enrollment rate of primary school in rural China is 100%.
#
# 		Partial pictures
# 			E.g. “Ninety percent of all our cars in this country in the last 10 years are still on road” (in fact, 90% of the cars were sold within the last three years)

# %% [markdown]
# ## 第三部分 统计描述 ##
#
# 本节只讨论一个参数的情况。
#
# #### 1.1 集中趋势
#
# - 均值
#
# *算术平均数*
#
# 用于度量数据的集中趋势，是最常见的集中趋势的度量，如同平衡点，易受极端数值影响
#
# $$ \overline{X} = \frac{\sum_{i=1}^{n}{x_i}}{n} = \frac{x_1 + x_2 + x_3 + ... + x_n}{n}$$
#
# *几何平均数*
#
# 常用于计算百分比、比率、指数、增长率等指标的平均数。
#
# 一般来说，几何平均数总是小于或等于算术平均数。
#
# $$ \overline{X} = \sqrt[n]{x_1\cdot x_2\cdot x_3\cdot\ldots\cdot x_n}$$
#
# 为了避免零增长率或负增长率，几何平均数的计算一般改为如下公式。中国的GDP增长率计算用的是实际GDP的几何平均数。
#
# $$ g = \sqrt[(n-1)]{\frac{x_2}{x_1} \cdot \frac{x_3}{x_2} \cdot \ldots \cdot \frac{x_n}{x_{n-1}}} $$
#
# *算术平均数和几何平均数的区别*
#
# 例：假定海淀区小学2004年入学人数为1万，2005年入学人数增加50％，而2006年减少50％。问从2004-2006年间入学人数平均变化情况是多少？
#
# 2005年的入学人数为1.5万；2006年的入学人数为0.75万。
#
# 年度变化的算术平均数为0，而年度变化的几何平均数为负13.4%。显然，几何平均数更适合度量入学人数在不同时期的变化。
#
# *加权平均数*
#
# 加权平均数：不同比重数据的平均数。公式为：
#
# $$ \overline{𝑋 ̄_𝑊}=\frac{(𝑊_1 𝑋_1+𝑊_2 𝑋_2+⋯𝑊_𝑁 𝑋_𝑁)}{(𝑊_1+𝑊_2+⋯+𝑊_𝑁)} $$
#
# 例如：一个学生某门课程期中成绩为72分，期末成绩为86分。期中和期末成绩分别占总成绩的40%和60％，问总成绩是多少？
#
# $$ \overline{𝑋 ̄_𝑊}=\frac{(72×0.4+86×0.6)}{(0.4+0.6)}=80.4$$
#
# 再如：
#
# 已知2000年三大产业从业人员的平均受教育年限分别为6.9年、7.8年和12.1年，问全体从业人员的平均受教育年限是多少？
#
# 不能用简单算术平均！
#
# 要先查找各个产业的从业人员数量，或比重。例如，知道2000年三大产业比重分别为50％、22.5％和27.5％。
#
# 全体从业人员的平均受教育年限是：
#
# $$ 0.5*6.9+0.225*7.8+0.275*12.1＝8.5 $$
#
# *调和平均数*
#
# 调和平均数：倒数的算术平均数的倒数。主要用来计算速度的平均。
#
# 公式：
# $$ \overline{X_H} = \frac{1}{\frac{1}{N}(\frac{1}{X_1} + \frac{1}{X_2} + \ldots + \frac{1}{X_n})}$$
#
# 例如：一个学生阅读2页书，读第一页时的速度折合为每小时20页，读第二页时的速度折合为每小时40页，问该生平均每小时阅读速度是多少？

# %%
cars.Price.mean()
# Out:
# 3159.4957983193276

# %%
cars.Mileage.mean()
# Out:
# 17.480407854984893

# %%
cars.groupby('Make').Mileage.mean().reset_index()
# Out:
#                           Make    Mileage
# 0          Ashok Leyland Stile  20.700000
# 1          Aston Martin Rapide   7.000000
# 2        Aston Martin Rapide S  11.900000
# 3     Aston Martin V12 Vantage   9.000000
# 4      Aston Martin V8 Vantage   5.000000
# 5        Aston Martin Vanquish   8.000000
# 6            Audi A3 Cabriolet  19.186667
# 7                      Audi A4  14.804000
# 8                      Audi A6  15.260000
# 9                      Audi A7  14.400000
# 10                   Audi A8 L  12.575000
# 11                     Audi Q3  16.260000
# 12                     Audi Q5  13.063333
# 13                     Audi Q7  12.466667
# 14                     Audi R8   9.515000
# 15                    Audi RS5   9.000000
# 16                    Audi RS6  10.410000
# 17                    Audi RS7  13.300000
# 18                     Audi S6  10.300000
# 19                     Audi TT   8.300000
# 20                BMW 1 Series  20.580000
# ...

# %% [markdown]
# - 中位数 Median
#
# 用于度量数据的集中趋势Central Tendency，为排序序列的中间值，如果 n 是奇数, 即为排序序列居中位置的观测值，如果 n 是偶数, 则为排序序列两个居中位置的观测值的均值，中位数在序列中的位置，不受数据极端值的影响
#
# - 众数 Mode
#
# 用于度量数据的集中趋势，为出现次数最多的数值，可从排序数组中观察得到，不受极值的影响，一组数据可能没有众数或有多个众数，对数值数据和类型数据均适用
#
# - 值域中点
#
# 用于度量数据的集中趋势，是最小和最大观测值的平均值，对数据的极端值非常敏感，常用于金融分析和气象预报。
#
# $$ Midpoint = \frac{X_{min} + X_{max}}{2} $$
#
# - 四分位数
#
# 用于度量数据的非集中趋势，把排序数据等分为四个区间，$Q_i$是第i个四分位数的位置
#
# ![](quartile.jpg)
#
# Q1，first quartile， 第一四分位数是处于（n+1)/4 位置上的观测值。 25%的观测值比第一四分位数小。
#
# Q2，second quartile,  第二四分位数就是中位数。处于2(n+1)/4 =（n+1)/2的位置上。50%的观测值比中位数小。
#
# Q3。 third quartile, 第三四分位数是处于 3(n+1)/4位置上的观测值。75%的观测值比第三四分位数小。
#
# - 中轴数
#
# 用于度量数据的集中趋势Central Tendency，是第一和第三四分位数的平均值，不受数据极端值的影响，Not Affected by Extreme Values
#
# $$ Medial\_Axis = \frac{Q_1 + Q_3}{2}$$

# %%
cars.Mileage.median()
# Out:
# 17.985

# %%
cars.Mileage.mode()
# Out:
# 0    20.5
# dtype: float64

# %%
cars.Type.mode()
# Out:
# 0    Sedan
# dtype: object

# %%
cars.Mileage.quantile(0.95)
# Out:
# 24.4

# %% [markdown]
# 假如某班1小组期末考试数学成绩为:
#
# 83,52,96,79,83,88,64,79,83,69
#
# 试描述数学成绩的集中趋势

# %%
scores = [83,52,96,79,83,88,64,79,83,69]

mean = sum(scores) / len(scores)

print(mean)
# Out:
# 77.6

# %%
scores.sort()

median = (scores[4] + scores[5]) / 2

print(median)
# Out:
# 81.0

# %% [markdown]
# #### 1.2 变异程度
#
# - 全距（极差）Range
#
# 度量数据的离散程度Measure of Dispersion，最大和最小观测值之差，不考虑数据如何分布取决于数据的极端值
#
# $$ Range = X_{max} - X_{min} $$
#
# - 限制全距 Restricted range
#
# 指95％分位数与5％分位数之差。其定义式如下：
#
# $$ Restricted\_Range = X_{p95} - X_{p5} $$
#
# - 四分位间距
#
# 度量数据的离散程度Measure of Dispersion，为第三和第一四分位数之差，
#
# $$ Inter\_Quartile\_Range = Q_3 - Q_1 $$
#
# 包括排序数据处于中间位置50%的观测值
#
# - 联合全距比率 Federal range ratio
#
# 指限制全距除以5％分位数。其定义式如下：
#
# $$ Federal\_range\_ratio = \frac{X_{p95} - X_{p5}}{X_{p5}}$$
#
# - 极值比
#
# 极值比为最大值与最小值之比，不考虑数据是如何分布的，只取决于数据的极端值。其公式为：
#
# $$ R = \frac{X_{max}}{X_{min}}$$
#
# - 限制极值比
#
# 应用极值比公式时需要注意最小值不能为0。有时为了消除奇异值，可以将极值比改为限制性极值比。它比较的一个接近于最大值（但一般不等于最大值）的数据与一个接近最小值（但一般不等于最小值）的数据之比。例如，95％分位数与5％分位数之比，90％分位数与10％分位数之比，第三四分位数与第一四分位数之比等。
#
# $$ RR = \frac{X_{p95}}{X_{p5}} $$

# %% [markdown]
# - 方差和标准差
#
# 度量数据的离散程度Measures of Dispersion，是最为常用的变异程度的度量，涉及数据的分布状况，表示全部观测值相对于均值的平均变异程度。样本方差的计算公式如下：
#
# $$ S^2 = \frac{\sum_{i=1}^{n}{(X_i-\overline{X})^2}}{n-1} = \frac{(X_1-\overline{X})^2 + (X_2-\overline{X})^2 + \ldots + (X_n-\overline{X})^2}{n-1} $$
#
# 当分母不是n-1而是N的时候，就是总体方差N。
#
# 标准差是方差的平方根：
#
# $$ S = \sqrt{\frac{\sum_{i=1}^{n}{(X_i-\overline{X})^2}}{n-1}} = \sqrt{\frac{(X_1-\overline{X})^2 + (X_2-\overline{X})^2 + \ldots + (X_n-\overline{X})^2}{n-1}}$$

# %%
cars.Mileage.var()
# Out:
# 21.018811179847432

# %%
cars.Mileage.std()
# Out:
# 4.5846277035161132

# %%
cars.describe()
# Out:
#               Price    BootSpace       Engine  FuelCapacity     Mileage
# count    833.000000   654.000000   826.000000    833.000000  662.000000
# mean    3159.495798   409.536697  1900.533898     51.341693   17.480408
# std     6272.519112   175.351525  1065.149758     17.643132    4.584628
# min      199.000000    80.000000   624.000000      0.000000    5.000000
# 25%      619.000000   256.000000  1248.000000     42.000000   14.000000
# 50%      880.000000   418.000000  1497.000000     50.000000   17.985000
# 75%     2329.000000   500.000000  2179.000000     64.000000   20.700000
# max    50000.000000  1000.000000  6592.000000    120.000000   30.000000

# %% [markdown]
# - 变异系数
#
# 度量相对离散程度（Measure of Relative Dispersion）,表现了标准差相对于均值的比率,用来比较两组或多组计量单位不同的数据的变异程度
#
# $$ CV = (\frac{S}{\overline{X}}) \cdot 100\% $$
#
# - 基尼系数
#
# 基尼系数是20世纪初意大利经济学家基尼根据洛伦茨曲线设计的判断收入分配平等程度的指标。收入分配越是趋向平等，基尼系数也越小，反之，收入分配越是趋向不平等，那么基尼系数也越大。联合国有关组织规定：若低于0.2表示收入绝对平均；0.2-0.3表示比较平均；0.3-0.4表示相对合理；0.4-0.5表示收入差距较大；0.6以上表示收入差距悬殊。
#
# <img style="float: left;" src="gini.png" height="480" width="480">
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
# 设实际收入分配曲线和收入分配绝对平等曲线之间的面积为A，实际收入分配曲线右下方的面积为B。并以A除以（A+B）的商表示不平等程度。这个数值被称为基尼系数或称洛伦茨系数。如果A为零，基尼系数为零，表示收入分配完全平等；如果B为零则系数为1，收入分配绝对不平等。该系数可在零和1之间取任何值。收入分配越是趋向平等，洛伦茨曲线的弧度越小，基尼系数也越小，反之，收入分配越是趋向不平等，洛伦茨曲线的弧度越大，那么基尼系数也越大。
#
# $$ Gini = 1 - \sum_{i=0}^{n-1}{(X_{i+1} - X_i)(Y_i + Y_{i+1})} = \sum_{i=1}^{n-1}{X_i Y_{i+1} - \sum_{i=1}^{n-1}{X_{i+1} Y_i}}$$
#
# 其中，X为累计人数比率；Y为累计收入比率；
#
# 也可以把基尼系数的计算公式写为：
#
# $$ Gini = 1 - \sum_{i=1}^{n}{\frac{1}{n}\cdot[2\sum_{j=1}^{i}{\frac{X_j}{\sum_{k=1}^{n}{X_k}} - \frac{X_i}{\sum_{k=1}^{n}{X_k}}}]}$$
#
# Gini系数的计算步骤：
#
# Step1：排序
#
# Step2：计算比重
#
# Step3：计算累积比重
#
# Step4：计算2倍的梯形面积
#
# Step5：计算基尼系数
#
# *基尼系数的性质*
#
# 基尼系数反映的是相对差异，不是绝对差异；
#
# 如果所有人的收入都有相同比例的增加或者减少，则基尼系数的数值保持改变；
#
# 如果所有人的收入都有相同数量的增加，则基尼系数的数值将变小。
#
# 基尼系数变小，则相对差异一定变小，但是绝对差异未必变小。
#
# 思考题：
#
# 有两个都只有三个人组成的社会，这两个社会中收入分配分别是（3，12，12）和（4，9，14）。
#
# 哪个社会更为平等？

# %% [markdown]
# #### 1.3 分布形状
#
# 形状（shape）表明数据是如何分布的，形状主要分为 偏态Skew 与 对称Symmetry 两类。
# 其中：
#
# 左偏: 均值<中位数
#
# 右偏: 均值>中位数
#
# 对称(零偏度) ：均值 = 中位数
#
# > a variable whose value is subject to variations due to chance (i.e. randomness, in a mathematical sense). A random variable can take on a set of possible different values (similarly to other mathematical variables), each with an associated probability [wiki](https://en.wikipedia.org/wiki/Random_variable)
#
# > Assigns a probability to each measurable subset of the possible outcomes of a random experiment, survey, or procedure of statistical inference. [wiki](https://en.wikipedia.org/wiki/Probability_distribution)
#
# 在这里相关概念包括离散概率分布、概率质量函数、连续概率分布、概率密度函数、累积分布函数，以及中心极限定理。
#
#
# #### 1.4 正态分布
#
# 钟形分布，也称为高斯分布。
#
# $$ f(x | \mu, \sigma) = \frac{1}{\sigma \sqrt{2\pi}}e^{-\frac{(x-\mu)^2}{2\sigma^2}}$$
#
# **PDF**
# <br>
# <br>
# <img style="float: left;" src="normal_pdf.png" height="320" width="320">
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **CDF**
# <br>
# <br>
#
#
# <img style="float: left;" src="normal_cdf.png" height="320" width="320">
#
# <br>
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
# #### 1.5 偏度与峰度
# > Measure of the asymmetry of the probability distribution of a real-valued random variable about its mean. [wiki](https://en.wikipedia.org/wiki/Skewness)
#
# <img style="float: left;" src="skewness.png" height="620" width="620">
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# > Measure of the "peakedness" of the probability distribution of a real-valued random variable [wiki](https://en.wikipedia.org/wiki/Kurtosis)
# <br>
# <br>
# <img style="float: left;" src="kurtosis.png" height="420" width="420">
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# #### 1.6 其他分布
#
# *二项分布*
#
# > Binomial distribution with parameters `n` and `p` is the discrete probability distribution of the number of successes in a sequence of n independent yes/no experiments, each of which yields success with probability p. A success/failure experiment is also called a Bernoulli experiment or Bernoulli trial; when n = 1, the binomial distribution is a Bernoulli distribution  [wiki](https://en.wikipedia.org/wiki/Binomial_distribution)
#
# $$ f(x | \mu, \sigma) = \frac{1}{\sigma\sqrt{2\pi}}e^{-\frac{(x-\mu)^2}{2\sigma^2}}$$
#
# *指数分布*
#
# > Probability distribution that describes the time between events in a Poisson process, i.e. a process in which events occur continuously and independently at a constant average rate. It has the key property of being memoryless. [wiki](https://en.wikipedia.org/wiki/Exponential_distribution)
#
# <br>
# <br>
# <img style="float: left;" src="exponential_pdf.png" height="420" width="420">
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# *均匀分布*
#
# > All values have the same frequency [wiki](https://en.wikipedia.org/wiki/Uniform_distribution_(continuous))
#
#
# <br>
# <br>
# <img style="float: left;" src="uniform.png" height="420" width="420">
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
#
#
# #### 1.7 6-sigma philosophy
# <img style="float: left;" src="6sigma.png" height="520" width="520">
#
# 身高（cm）：102.8
# SD  3.9

# %% [markdown]
# #### 1.8 直方图与散点图
#
# 通常我们用直方图、散点图来表示数据的分布。

# %%
import seaborn as sns
sns.set(color_codes=True)
# %matplotlib inline

# %%
#把缺失值替换为均值
cars.Mileage.fillna(cars.Mileage.mean(), inplace=True)

# %%
sns.distplot(cars.Mileage, kde=False)

# %%
sns.distplot(cars.Mileage, bins=range(0,50,1))

# %% [markdown]
# #利用scipy来查看分布

# %%
from scipy import stats
import scipy as sp
import matplotlib as mpl
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#生成正态分布的随机数
random_normal = sp.randn(100)
plt.scatter(range(100), random_normal)

# %%
#查看该分布的均值和方差
print("mean:", random_normal.mean(), " variance:", random_normal.var())
# Out:
# mean: 0.161767557964  variance: 1.0707947036

# %%
#创建正态分布，均值为2.5，标准差为1.7

n = stats.norm(loc=2.5, scale=1.7)

# %%
#从n中生成数值
n.rvs()
# Out:
# 5.5985712652251234

# %%
#求0.3处的概率密度函数
n.pdf(0.3)
# Out:
# 0.10157711386142985

# %%
#二项分布 p = 0.4 n = 15
stats.binom.pmf(range(15), 10, 0.4)

# %% [markdown]
# ## 第四部分 假设检验 ##
#
# ### 1. 基础知识
#
# #### 1.1 假设的类型 Types of Hypotheses
#
# 假设是对总体参数的一种推断，也就是说，我们希望通过观察样本的特征，来判断总体是否具有同样的特征。
#
# > 总体参数：均值、比率和方差
#
# > 进行分析前必须先识别参数
#
# 零假设 The Null Hypothesis
#
#
# 1.  陈述需要检验的假设
#
# 	例如: $ H_0: \mu = 50 $
#
# 2.  零假设用 H0 表示
# 3.  代表“通常”的情形 “Business as usual”
# 4.  总是包含等号“=” （比如=, $\geq$, $\leq$)
# 5.  检验以“假定零假设为真”开始
#
#
# 备择假设 The Alternative Hypothesis
#
#
# 1.	备择假设为零假设的对立情况并且表明了H0被拒绝后的可得出的结论
# 	例如: H1:$\mu \neq 50$
# 2.	备择假设用H1表示
# 3. 表示对“通常”情形挑战
#     Captures the challenge to ‘Business as Usual’
# 4. 从不包含等号
#
# *那么如何建立假设呢？*
#
# 总体的平均看电视时间为12小时吗？
#
# $$\mu = 12 \qquad \mu \neq 12 \qquad H_0:\mu = 12 \qquad H_1: \mu \neq 12$$
#
# 总体平均看电视时间并非12小时吗？
#
# $$\mu \neq 12 \qquad \mu = 12 \qquad H_0:\mu \neq 12 \qquad H_1: \mu = 12$$
#
# 一顶帽子的花费小于等于$20吗?
#
# $$ H_0:\mu\leq20 \qquad H_1:\mu>20$$
#
# 书店里平均消费大于$25吗?
#
# $$ H_0:\mu\geq25 \qquad H_1:\mu<25$$
#
# *现实问题的假设设立 Identifying Hypotheses in Problems*
#
# 1. 检验的是总体参数，不是样本统计量
# 2. 两种假设具有互斥性和完备性                              mutually exclusive & exhaustive
# 3. 有时先设定备择假设较为容易
#
#     如要检验总体平均年龄是否小于50岁？
#
#     原问题的统计学表述为 $H_0: \mu\geq50$
#
#     对立情况的统计学表述 $H_1: \mu <50$
#
# #### 1.2 显著性水平$\alpha$ Level of Significance
#
# 1.	显著性水平常用$\alpha$ 表示，决定零假设为真情况下样本统计量不大可能的取值的区间，决定了检验的临界值和拒绝域的大小。
# 2.	实际应用中，$\alpha$ 的值往往由研究人员在检验开始时选定，通常取决于出现第一类错误的代价。在第一类错误可能导致严重后果的情况下,取$\alpha$＝.05或者更小的值。
# 3. $1 - \alpha$ 表示置信水平
#
# ![](hypothis.png)
#
# ![](hypothis_2.png)
#
# ![](rejection.png)
#
# #### 1.3 检验决策错误 Errors in Making Decision
#
# 第一类错误 Type I Error
#
# 否真错误, 后果往往较为严重
#
# 出现第一类错误的概率为 $\alpha$
#
# 等于显著性水平 Level of Significance
#
# 第二类错误 Type II Error
#
# 存伪错误, 出现第二类错误的概率为 $\beta$
#
# 类似法庭裁决：第一类错误如同是陪审团裁定被告有罪，可事实上
# 被告是无辜的。第二类错误如同被告被裁定无罪然而事实上有罪。
#
# ![](twoerror.png)
#
# **注意：**
#
# $\alpha$和$\beta$存在反向关系,不能同时降低两类错误。
#
# *影响$\beta$的因素*
#
# 1.	总体参数的真值
#
# 假设值与真值之差越大，$\beta$值越小
#
# 2. 总体的标准差 $\sigma$
#
# 随着$\sigma$的减小，$\beta$值减小
#
# 3. 显著性水平 $\alpha$
#
# 随着 $\alpha$值的增大，$\beta$值减小
#
# 4.	样本容量 n
#
# 随着样本容量的增大，$\beta$值减小
#
# ---
#
# 对于给定的$\alpha$值，增加样本容量会降低$\beta$值，从而提高检验能力
#
# 对于给定的样本，我们必须考虑两类错误之间此起彼伏的关系，降低出现第一类错误的风险会提高出现第二类错误的风险。
#
# 只有当$H_0$为真时才有置信度与第一类错误的概念；检验能力及第二类错误的风险只有当$H_1$为真时，才有意义。
#
# ---
#
# ### 2. 假设检验过程 Test Process
#
# 1）设定$H_0$ 和 $H_1$
#
# 2）选择检验方法和统计量
#
# > 一般来说，可根据样本情况和检验目标来选择T检验、Z检验、F检验、$\chi^2$检验、ANOVA等五种，对应的统计量分别为T值、Z值、F值、$\chi^2$值、F值
#
# 3）选择显著水平 $\alpha$，确定拒绝域和接受域
#
# 4）计算样本统计量的值(T值、Z值、F值、$\chi^2$值、F值)，及其对应的p值。
#
# 5）根据判别准则作出判断，如果p值小于$\alpha$，拒绝零假设，否则不拒绝零假设。

# %%
cars.head(20)
# Out:
#                         Make                                        Model  \
# 0        Ashok Leyland Stile        Ashok Leyland Stile LE 8-STR (Diesel)
# 1        Ashok Leyland Stile        Ashok Leyland Stile LS 8-STR (Diesel)
# 2        Ashok Leyland Stile        Ashok Leyland Stile LX 8-STR (Diesel)
# 3        Ashok Leyland Stile        Ashok Leyland Stile LS 7-STR (Diesel)
# 4        Ashok Leyland Stile  Ashok Leyland Stile LS 7-STR Alloy (Diesel)
# 5        Ashok Leyland Stile        Ashok Leyland Stile LX 7-STR (Diesel)
# 6        Ashok Leyland Stile  Ashok Leyland Stile LX 7-STR Alloy (Diesel)
# 7        Aston Martin Rapide            Aston Martin Rapide LUXE (Petrol)
# 8      Aston Martin Rapide S               Aston Martin Rapide S (Petrol)
# 9   Aston Martin V12 Vantage      Aston Martin V12 Vantage Coupe (Petrol)
# 10   Aston Martin V8 Vantage       Aston Martin V8 Vantage Coupe (Petrol)
# 11   Aston Martin V8 Vantage     Aston Martin V8 Vantage S Coupe (Petrol)
# ...

# %% [markdown]
# 【例子】手动挡汽车与自动挡汽车的平均英里数（mileage）是否有显著的差别？

# %%
cars_Automatic = cars[cars.GearType==' Automatic'].copy().reset_index()
cars_Manual = cars[cars.GearType==' Manual'].copy().reset_index()

# %%
print("Average Mileage of Automatic cars:", cars_Automatic.Mileage.mean())
print("Average Mileage of Manual cars:", cars_Manual.Mileage.mean())
# Out:
# Average Mileage of Automatic cars: 16.0299593526
# Average Mileage of Manual cars: 18.759826876

# %%
#手动挡汽车英里数的平均值和标准差
print("Mean of Manual Cars:", cars_Manual.Mileage.mean())
print("Standard Deviation of Manual Cars:", cars_Manual.Mileage.std())
# Out:
# Mean of Manual Cars: 18.759826876
# Standard Deviation of Manual Cars: 3.39116432057

# %%
#自动挡汽车英里数的平均值和标准差
print("Mean of Automatic Cars:", cars_Automatic.Mileage.mean())
print("Standard Deviation of Automatic Cars:", cars_Automatic.Mileage.std())
# Out:
# Mean of Automatic Cars: 16.0299593526
# Standard Deviation of Automatic Cars: 4.42796867968

# %%
#手动挡汽车英里数均值的置信区间
stats.norm.interval(0.95, loc=cars_Manual.Mileage.mean(), scale = cars_Manual.Mileage.std()/np.sqrt(len(cars_Manual)))
# Out:
# (18.435893365656611, 19.083760386379616)

# %%
#自动挡汽车英里数均值的置信区间
stats.norm.interval(0.95, loc=cars_Automatic.Mileage.mean(), scale = cars_Automatic.Mileage.std()/np.sqrt(len(cars_Automatic)))
# Out:
# (15.579991837567594, 16.479926867561854)

# %%
#效应量
print("Effect size:", cars_Manual.Mileage.mean() - cars_Automatic.Mileage.mean())
# Out:
# Effect size: 2.72986752345

# %% [markdown]
# 在这个例子中，我们可以进行t检验来进行均值比较。
#
# t检验的零假设是：$\mu_1 = \mu_2$
#
# 也就是说，本例的零假设是：平均来看，手动挡车和自动挡车的英里数没有显著差别
#
# 下面我们进行t检验并确定p值

# %%
stats.ttest_ind(cars_Manual.Mileage, cars_Automatic.Mileage, equal_var=True)
# Out:
# Ttest_indResult(statistic=9.8070502794060701, pvalue=1.6645045869210697e-21)

# %% [markdown]
# p值是效应量发生的概率，而在本例中，p值接近于0
#
# 结论：小概率事件竟然发生了，那么我们应该拒绝原假设，并认为手动挡汽车和自动挡汽车的平均英里数有显著差别。

# %% [markdown]
# ### 3. 假设检验有哪些？
#
# [关于假设检验，T检验 F检验 卡方检验 和 ANOVA 这些检验在什么情况下使用，它们的区别是什么？](https://www.zhihu.com/question/309884517/answer/579315142)
